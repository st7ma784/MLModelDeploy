# %% [markdown]
# <a href="https://colab.research.google.com/github/st7ma784/MLModelDeploy/blob/main/DemoColabTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://YOURGITUSERNAME:YOURPAT@github.com/YOURGITUSERNAME/YOUREPO.git
# Out:
#      |████████████████████████████████| 4.7 MB 8.9 MB/s
#      |████████████████████████████████| 101 kB 10.4 MB/s
#      |████████████████████████████████| 6.6 MB 59.5 MB/s
# fatal: destination path 'NDimRL' already exists and is not an empty directory.

# %%
##Pull Data -- in this case its from Git hub, if you've written your DataModule correctly, you shouldnt need this
# %cd YOURREPO
# !git submodule init
# !git submodule update
# %ls
# !pip install -r requirements.txt --quiet ## Assume you have this? Super useful for conda/pip installs
# Out:
# [Errno 2] No such file or directory: 'NDimRL'
# /content/NDimRL
# fatal: No url found for submodule path 'MS-COCO-ES' in .gitmodules
# BuildSpainDataSet.py  MS-COCO-ES/       README.md      trainclip_v2.py
# LICENSE               NDimHECAgent.com  trainagent.py  trainsweep.py

# %%
from trainclip_v2 import train

config={
        "batchsize":12,         #[1,4,8,16,32,64]
        "learning_rate":4e-6,   #[2e-4,1e-4,5e-5,2e-5,1e-5,4e-6]
        "precision":16,         #[32,16,'bf16']
    }
train(config)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   "Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. "
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.13.1
# Run data is saved locally in <code>/content/NDimRL/wandb/run-20220808_173055-3q7a5ip7</code>
# Syncing run <strong><a href="https://wandb.ai/st7ma784/6DIMContrSweep/runs/3q7a5ip7" target="_blank">light-dragon-58</a></strong> to <a href="https://wandb.ai/st7ma784/6DIMContrSweep" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ...
